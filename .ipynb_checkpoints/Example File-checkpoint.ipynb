# %%
import bank.accounts.account as acct
import bank.accounts.chequing as ch
import bank.accounts.saving as sv

# %%
#ch.Chequing?
ac1 = ch.Chequing("Conrad",100000)
print(ac1.name)
print(ac1.bal)
print(ac1.bal_hist)
print(ac1.bal_time)
print(ac1.recent_transact)
print(ac1.trans_time)
print(ac1.trans_lim)
print(ac1.actype)
# Out:
# Conrad
# 100000
# [100000]
# ['2020/12/02, 17:02:29']
# []
# []
# 1000
# Chequings

# %%
ac1 = ch.Chequing(123123,1000.1231231)
ac1 = ch.Chequing("Conrad",-1000.1231231) #Raised Nonimplemented Error
# Out:
# Please enter a name. Cannot have numerical values.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-3-4d3947057b8d> in <module>
#       1 ac1 = ch.Chequing(123123,1000.1231231)
# ----> 2 ac1 = ch.Chequing("Conrad",-1000.1231231) #Raised Nonimplemented Error
#
# ~\Desktop\Work\Data 533\Data-533-Lab-2\bank\accounts\chequing.py in __init__(self, name, amount, maxlimit)
#      77         '''
#      78         if amount < 0 or maxlimit < 0:
# ---> 79             raise NotImplementedError("Initial deposit and max limit must be non-negative.\n")
#      80
#      81         for i in str(name):
#
# NotImplementedError: Initial deposit and max limit must be non-negative.

# %%
ac1 = ch.Chequing("Conrad",100000)
ac1.deposit(-10) 
ac1.bal
ac1.deposit(0) #2
ac1.deposit(1.1231) #3
ac1.withdraw(0) #4
ac1.withdraw(1000) #5
ac1.withdraw(-123123)
ac1.ac
# Out:
# Amount to deposit must be greater than 0.
#
# $0.00 has been deposited to account 41232284.
# Current balance: $100000.00.
#
# $1.12 has been deposited to account 41232284.
# Current balance: $100001.12.
#
# $0.00 has been withdrawn from account 41232284.
# Current balance: $100001.12.
#
# $1000.00 has been withdrawn from account 41232284.
# Current balance: $99001.12.
#
# Amount to withdraw must be greater than 0.
# 41232284

# %%
ac1.bal
ac1.details()
ac1.withdraw(1001)
ac1.summary()
# Out:
# The account holder is: Conrad.
# The account number is: 41232284.
# The account type is: Chequings
# Your current balance is: $99001.12.
# Your current transaction limit is: $1000.00.
#
# Your current transaction limit is $1000.00, therefore you are unable to withdraw the requested amount of $1001.00.
#
# Account Holder: Conrad.
# Current Balance: $99001.12.
# Your balance history for the past 30 transcations:

# %%
ac1.change_lim(0)
ac1.withdraw(1)
ac1.change_lim(-10)
ac1.change_lim(10)
ac1.withdraw(10)
ac1.change_lim(ac1.bal+1)
ac1.withdraw(ac1.bal+1)
ac1.withdraw(ac1.bal)
# Out:
# Your transaction limit has decreased from $1000.00 to $0.00.
#
# Your current transaction limit is $0.00, therefore you are unable to withdraw the requested amount of $1.00.
#
# Account limit must be greater than 0.
#
# Your transaction limit has increased from $0.00 to $10.00.
#
# $10.00 has been withdrawn from account 41232284.
# Current balance: $98991.12.
#
# Your transaction limit has increased from $10.00 to $98992.12.
#
# You do not have enough funds to withdraw 98992.12.
#
# $98991.12 has been withdrawn from account 41232284.
# Current balance: $0.00.

# %%
ac1 = sv.Saving("Conrad",100000)
print(ac1.name)
print(ac1.bal)
print(ac1.bal_hist)
print(ac1.bal_time)
print(ac1.recent_transact)
print(ac1.trans_time)
print(ac1.trans_lim)
print(ac1.actype)
print(ac1.intrate)
print(ac1.fixed_amount)
print(ac1.datestart)
print(ac1.dateend)
print(ac1.fix_dep_inprocess)
# Out:
# Conrad
# 100000
# [100000]
# ['2020/12/02, 17:02:37']
# []
# []
# 1000
# Savings
# 0.01
# 0
# 0
# 0
# 0

# %%
ac1 = sv.Saving("Con123d",100000)
ac1 = sv.Saving("Cawdd",-100000) #NotImplemented Error
# Out:
# Please enter a name. Cannot have numerical values.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-78c9b5cff9b3> in <module>
#       1 ac1 = sv.Saving("Con123d",100000)
# ----> 2 ac1 = sv.Saving("Cawdd",-100000) #NotImplemented Error
#
# ~\Desktop\Work\Data 533\Data-533-Lab-2\bank\accounts\saving.py in __init__(self, name, amount, maxlimit)
#      96         '''
#      97         if amount < 0 or maxlimit < 0:
# ---> 98             raise NotImplementedError("Initial deposit, max limit and interest rate must be non-negative.")
#      99
#     100         for i in str(name):
#
# NotImplementedError: Initial deposit, max limit and interest rate must be non-negative.

# %%
ac1 = sv.Saving("Conrad",1000)
ac1.deposit(-10)
ac1.deposit(25) #2
ac1.withdraw(0)
ac1.withdraw(250) #3
ac1.withdraw(10000) 
ac1.change_lim(1500)
ac1.withdraw(1500) 
ac1.withdraw(700) #4
ac1.deposit(500) #5
# Out:
# Amount to deposit must be greater than 0.
#
# $25.00 has been deposited to account 14640816.
# Current balance: $1025.00.
#
# $0.00 has been withdrawn from account 14640816.
# Current balance: $1025.00.
#
# $250.00 has been withdrawn from account 14640816.
# Current balance: $775.00.
#
# Your current transaction limit is $1000.00, therefore you are unable to withdraw the requested amount of $10000.00.
#
# Your transaction limit has increased from $1000.00 to $1500.00.
#
# You do not have enough funds to withdraw 1500.00.
#
# $700.00 has been withdrawn from account 14640816.
# Current balance: $75.00.
#
# $500.00 has been deposited to account 14640816.
# Current balance: $575.00.

# %%
ac1.bal
ac1.details()
ac1.summary()
# Out:
# The account holder is: Conrad.
# The account number is: 14640816.
# The account type is: Savings
# Your current balance is: $575.00.
# Your current transaction limit is: $1500.00.
# --------------------------------------------
# You currently have no fixed deposits in process.
#
# Account Holder: Conrad.
# Current Balance: $575.00.
# Your balance history for the past 30 transcations:

# %%
ac1.setfixdeposit()
ac1.setfixdeposit(500)
ac1.details()
ac1.setfixdeposit(600)
ac1.setfixdeposit(200,0.01,True)
# Out:
# Amount for a fixed deposit and interest rate must be greater than 0.
#
# Your deposit of $500.00 has been fixed for a year with an interest rate of 1.00%.
# On 2021/12/02, $505.0 will be added to your Savings account.
#
# The account holder is: Conrad.
# The account number is: 14640816.
# The account type is: Savings
# Your current balance is: $575.00.
# Your current transaction limit is: $1500.00.
# --------------------------------------------
# You currently have $500.00 fixed at an interest rate of 1.00%.
# On 2021/12/02, $505.0 will be added to your Savings account.
#
# You already have a fixed deposit in process. The current amount locked in is $500.00 at a rate of 1.00. The amount will be made available on 2021/12/02.
#
# Your fixed depot created on 2020/12/02 is complete.
#
# $505.00 has been deposited to account 14640816.
# Current balance: $1080.00.

# %%
ac1.details()
ac1.summary()
# Out:
# The account holder is: Conrad.
# The account number is: 14640816.
# The account type is: Savings
# Your current balance is: $1080.00.
# Your current transaction limit is: $1500.00.
# --------------------------------------------
# You currently have no fixed deposits in process.
#
# Account Holder: Conrad.
# Current Balance: $1080.00.
# Your balance history for the past 30 transcations:
